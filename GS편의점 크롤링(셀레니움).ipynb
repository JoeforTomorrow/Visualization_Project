# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
def get_chrome_driver():
    # 1. 크롬 옵션 세팅
    chrome_options = webdriver.ChromeOptions()
    
    # 2. driver 생성하기
    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()), # 가장 많이 바뀐 부분
        options=chrome_options
    )
    
    return driver

# %%
driver = get_chrome_driver()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [C:\Users\asxs0\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
driver.get("http://gs25.gsretail.com/gscvs/ko/store-services/locations#;")#해당 페이지로 들어감

# %%
driver.find_element_by_xpath('//*[@id="stb1"]/option[2]').click() #지역 선택에서 서울시 선택
# Out:
# C:\Users\asxs0\AppData\Local\Temp/ipykernel_36552/625883079.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="stb1"]/option[2]').click() #지역 선택에서 서울시 선택

# %%
driver.find_element_by_xpath('//*[@id="searchButton"]').click() #검색 누르기
# Out:
# C:\Users\asxs0\AppData\Local\Temp/ipykernel_36552/1428001225.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="searchButton"]').click() #검색 누르기

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') #스크롤 맨 아래로

# %%
#한페이지 긁고 넘어가고
import time
import pandas as pd
datas = pd.DataFrame()
salist=[]
#테스트용 코드
# store = driver.find_elements_by_xpath('//*[@id="storeInfoList"]/tr[1]/td[1]/a')
# address = driver.find_elements_by_xpath('//*[@id="storeInfoList"]/tr[1]/td[2]/a')
# print(store[0].text)
# print(address[0].text)

#exception 날때까지 긁음
while True:
    try:
        for i in range (1,6):    
            store = driver.find_elements_by_xpath(f'//*[@id="storeInfoList"]/tr[{i}]/td[1]/a')#지점명
            address = driver.find_elements_by_xpath(f'//*[@id="storeInfoList"]/tr[{i}]/td[2]/a')#주소
            salist = [[store[0].text, address[0].text]]#받은거 리스트로 저장
            #print(store[0].text)
            #print(address[0].text)
            dff = pd.DataFrame(salist, columns=['지점명','주소'])#데이터프레임으로 만들기
            datas = pd.concat([datas, dff])#빈 데이터프레임에 쌓기
        driver.find_element_by_xpath('//*[@id="pagingTagBox"]/a[3]').click()#다음 페이지로 넘김
        print("한페이지 끝")
        time.sleep(2) # 이거 안하면 페이지 로딩전에 긁어버려서 망함
    except Exception as e:
        print("끝이거나 오류",e)
        break
            
     
print(datas)
# Out:
# C:\Users\asxs0\AppData\Local\Temp/ipykernel_36552/3597070336.py:16: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   store = driver.find_elements_by_xpath(f'//*[@id="storeInfoList"]/tr[{i}]/td[1]/a')#지점명
# C:\Users\asxs0\AppData\Local\Temp/ipykernel_36552/3597070336.py:17: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   address = driver.find_elements_by_xpath(f'//*[@id="storeInfoList"]/tr[{i}]/td[2]/a')#주소
# C:\Users\asxs0\AppData\Local\Temp/ipykernel_36552/3597070336.py:23: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="pagingTagBox"]/a[3]').click()#다음 페이지로 넘김
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 한페이지 끝
# 끝이거나 오류 list index out of range
#             지점명                                                 주소
# 0      GS25CBS점             서울 양천구 목동서로159-1 (목1동 917-1, CBS방송국1층)
# 0     GS25DDMC점                  서울 마포구 매봉산로75, 1층 107호 (상암동 1610)
# 0   GS25DMC가재울점         서울 서대문구 가재울미래로2, 203동 101호 (남가좌동 385, 2단지)
# 0      GS25G고덕점                         서울 강동구 고덕로39 (암사3동 441-14)
# 0    GS25G국회대로점                        서울 영등포구 국회대로746 (여의도동 17-2)
# ..          ...                                                ...
# 0      H&B우장산역점                         서울 강서구 강서로251 (내발산동 723-9)
# 0      S2상왕십리역점   서울 성동구 왕십리로지하 374, 207-02호 (하왕십리동 946-14, 상왕십리역)
# 0        S4동작역점  서울 동작구 현충로257, 431-02호 (동작동 327-1, 4호선 동작역 Don...
# 0        경희프라자점       서울 동대문구 경희대로23, 문화복지시설 101호 (회기동 1-5, 전면플라자)
# 0        나만의냉장고                            서울 강남구 논현로508 (역삼동 679)
#
# [3061 rows x 2 columns]

# %%
#csv로 저장
datas.to_csv("GS편의점 지점정보.csv", mode='a', header = False, encoding='cp949')
